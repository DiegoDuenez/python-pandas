# %%
import pandas as pd

columns = ["marca", "precio", "disponibilidad"]

cocheA = ["Mercedes", 10000, True]
cocheB = ["BMW", 20000, False]

df = pd.DataFrame([cocheA, cocheB], columns=columns)
df
# Out:
#       marca  precio  disponibilidad
# 0  Mercedes   10000            True
# 1       BMW   20000           False

# %%
import pandas as pd

columns = ["marca", "precio", "disponibilidad"]

marcas = [
    'Audi',
    'Ferrari',
    'Toyota',
    'BMW'
]

precio = [
    100000,
    200000,
    300000,
    400000
]

disponibilidad = [
    True,
    False,
    True,
    True
]

df = pd.DataFrame(
    list(zip(marcas, precio, disponibilidad)),
    columns=columns
)

df
# Out:
#      marca  precio  disponibilidad
# 0     Audi  100000            True
# 1  Ferrari  200000           False
# 2   Toyota  300000            True
# 3      BMW  400000            True

# %%
import pandas as pd

columns = ["marca", "precio", "disponibilidad"]

marcas = [
    'Audi',
    'Ferrari',
    'Toyota',
    'BMW'
]

precio = [
    100000,
    200000,
    300000,
    400000
]

disponibilidad = [
    True,
    False,
    True,
    True
]


diccionario = {
    "marca": marcas,
    "precio": precio,
    "disponibilidad": disponibilidad
}

df = pd.DataFrame(diccionario)
df
# Out:
#      marca  precio  disponibilidad
# 0     Audi  100000            True
# 1  Ferrari  200000           False
# 2   Toyota  300000            True
# 3      BMW  400000            True

# %%
import pandas as pd

df = pd.read_csv('datos.csv', delimiter=',') 

df
# Out:
#      marca   precio  disponibilidad
# 0     Audi   100000            True
# 1  Ferrari    20000           False
# 2   Toyota    20000            True

# %%
import pandas as pd

dfs = pd.read_html('datos.html')

dfs
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\xampp\htdocs\Python\main.ipynb Cell 5' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/xampp/htdocs/Python/main.ipynb#ch0000005?line=0'>1</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/c%3A/xampp/htdocs/Python/main.ipynb#ch0000005?line=2'>3</a> dfs = pd.read_html('datos.html')
#       <a href='vscode-notebook-cell:/c%3A/xampp/htdocs/Python/main.ipynb#ch0000005?line=4'>5</a> dfs
#
# File c:\Users\Desarrollo\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\Desarrollo\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\html.py:1113, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1109 validate_header_arg(header)
#    1111 io = stringify_path(io)
# -> 1113 return _parse(
#    1114     flavor=flavor,
#    1115     io=io,
#    1116     match=match,
#    1117     header=header,
#    1118     index_col=index_col,
#    1119     skiprows=skiprows,
#    1120     parse_dates=parse_dates,
#    1121     thousands=thousands,
#    1122     attrs=attrs,
#    1123     encoding=encoding,
#    1124     decimal=decimal,
#    1125     converters=converters,
#    1126     na_values=na_values,
#    1127     keep_default_na=keep_default_na,
#    1128     displayed_only=displayed_only,
#    1129 )
#
# File c:\Users\Desarrollo\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\html.py:915, in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     913 retained = None
#     914 for flav in flavor:
# --> 915     parser = _parser_dispatch(flav)
#     916     p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     918     try:
#
# File c:\Users\Desarrollo\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\html.py:872, in _parser_dispatch(flavor)
#     870 else:
#     871     if not _HAS_LXML:
# --> 872         raise ImportError("lxml not found, please install it")
#     873 return _valid_parsers[flavor]
#
# ImportError: lxml not found, please install it
